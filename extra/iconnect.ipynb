# %%
import pandas as pd

# %%
df=pd.read_excel("xyz.xlsx")

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                                       0
# Regional Location of the Dealership                                                                                             0
# Enter Dealer Code                                                                                                               2
# 1. "Customers seem interested in downloading the i-Connect app when introduced to it."                                          0
# 2. Which i-Connect feature category do you talk about the most when explaining the app to customers?                            0
# 3. What material do you mostly use to promote the i-Connect app?                                                                0
# Do you need any other material to promote the i-Connect app? \nIf yes, mention suggested material.                            337
# ...

# %%
df.groupby('Enter Dealer').count()
# Out:
#                                                     Timestamp  \
# 8. How would you rate the ease of use of the ap...
# 1                                                           1
# 2                                                           1
# 3                                                           1
# 4                                                           4
# 5                                                           7
# 6                                                           9
# 7                                                          18
# 8                                                          54
# 9                                                          74
# 10                                                        486
#
#                                                     Regional Location of the Dealership  \
# 8. How would you rate the ease of use of the ap...
# 1                                                                                     1
# ...
